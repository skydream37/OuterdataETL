# %%
import pandas as pd
df = pd.read_csv('tag_pandas.csv')
df = df.drop(df.index[1097:])
df = df.drop(df.index[0])
df
# Out:
#                洗髮精     洗髮乳      蘆薈      護髮      檸檬      精油     維他命     潤髮乳  \
# 2014-01-01  0.0023  0.0060  0.0013  0.0058  0.0041  0.0012  0.0102  0.0023
# 2014-01-02  0.0013  0.0021  0.0023  0.0035  0.0051  0.0018  0.0034  0.0015
# 2014-01-03  0.0013  0.0039  0.0040  0.0035  0.0039  0.0035  0.0034  0.0015
# 2014-01-04  0.0005  0.0018  0.0010  0.0070  0.0027  0.0047  0.0001  0.0023
# 2014-01-05  0.0010  0.0024  0.0033  0.0047  0.0029  0.0018  0.0034  0.0023
# 2014-01-06  0.0008  0.0018  0.0030  0.0035  0.0027  0.0006  0.0068  0.0008
# 2014-01-07  0.0013  0.0042  0.0010  0.0058  0.0061  0.0024  0.0001  0.0038
# 2014-01-08  0.0003  0.0018  0.0030  0.0012  0.0032  0.0018  0.0001  0.0030
# 2014-01-09  0.0005  0.0015  0.0017  0.0035  0.0005  0.0029  0.0001  0.0030
# 2014-01-10  0.0008  0.0036  0.0043  0.0035  0.0024  0.0018  0.0034  0.0015
# 2014-01-11  0.0011  0.0027  0.0023  0.0012  0.0039  0.0012  0.0001  0.0038
# ...

# %%
df.to_csv('tag_pandas_cut.csv', sep=',', encoding='utf-8',index_label=False)

# %%
name_1 = df.iloc[:,1].name
name_2 = df.iloc[:,2].name

# %%
from scipy.stats.stats import pearsonr
v_1 = df.iloc[:,1]
v_2 = df.iloc[:,2]
p = pearsonr(v_1,v_2)
p
# Out:
# (0.14855204975026631, 7.8215595497619933e-07)

# %%
import numpy
numpy.corrcoef(v_1,v_2)
# Out:
# array([[ 1.        ,  0.14855205],
#        [ 0.14855205,  1.        ]])
